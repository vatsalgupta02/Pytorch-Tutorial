# %% [markdown]
# # Convolution Neural Networks

# %%
import torch
import numpy as np

# %% [markdown]
# ## Loading the DATA

# %%
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler

num_workers = 0
batch_size = 20
valid_size = 0.2

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_data = datasets.CIFAR10('data', train=True, download=True, transform=transform)
test_data = datasets.CIFAR10('data', train=False, download=True, transform=transform)

num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                           sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                           sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size,
                                          num_workers=num_workers)

classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Visualizing the data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def imshow(img):
    img = img/2 + 0.5
    plt.imshow(np.transpose(img, (1, 2, 0)))

# %%
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])
# Out:
# <ipython-input-4-ab31463b682e>:7: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])

# %%
rgb_img = np.squeeze(images[3])
channels = ['red channel', 'green channel', 'blue channel']

fig = plt.figure(figsize = (36, 36)) 
for idx in np.arange(rgb_img.shape[0]):
    ax = fig.add_subplot(1, 3, idx + 1)
    img = rgb_img[idx]
    ax.imshow(img, cmap='gray')
    ax.set_title(channels[idx])
    width, height = img.shape
    thresh = img.max()/2.5
    for x in range(width):
        for y in range(height):
            val = round(img[x][y],2) if img[x][y] !=0 else 0
            ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center', size=8,
                    color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ## Defining the Network Architecture

# %%
from torch import nn
import torch.nn.functional as F

class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)
        
        self.pool = nn.MaxPool2d(2, 2)
        
        self.fc1 = nn.Linear(4 * 4 * 128, 512)
        self.fc2 = nn.Linear(512, 128)
        self.output = nn.Linear(128, 10)
        
        self.dropout = nn.Dropout(0.25)
        
    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 128 * 4 * 4)
        x = self.dropout(x)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.output(x)
        return x
    
model = Network()
print(model)
# Out:
# Network(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=2048, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=128, bias=True)
#   (output): Linear(in_features=128, out_features=10, bias=True)
#   (dropout): Dropout(p=0.25, inplace=False)
# )

# %%
# test for cuda
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('training on : ', device)
# model.cuda()
model.to(device)
# Out:
# training on :  cuda:0
# Network(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=2048, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=128, bias=True)
#   (output): Linear(in_features=128, out_features=10, bias=True)
#   (dropout): Dropout(p=0.25, inplace=False)
# )

# %% [markdown]
# ## Training the Network

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.005)
criterion = nn.CrossEntropyLoss()

# %%
n_epochs = 50
valid_loss_min = np.Inf

for epoch in range(n_epochs):
    train_loss, valid_loss = 0.0, 0.0
    
    model.train()
    for images, labels in train_loader:
        
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        op = model(images)
        loss = criterion(op, labels)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        
    model.eval()
    for images, labels in valid_loader:
        images, labels = images.to(device), labels.to(device)
        op = model(images)
        loss = criterion(op, labels)
        valid_loss += loss.item()
    
    train_loss = train_loss/len(train_loader)
    valid_loss = valid_loss/len(test_loader)
        
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(epoch+1, train_loss, valid_loss))
    
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f}--> {:.6f}).\tSaving model ...\n'.format(valid_loss_min, valid_loss))
        torch.save(model.state_dict(), 'model.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 2.295164 	Validation Loss: 2.264661
# Validation loss decreased (inf--> 2.264661).	Saving model ...
#
# Epoch: 2 	Training Loss: 2.092519 	Validation Loss: 1.915924
# Validation loss decreased (2.264661--> 1.915924).	Saving model ...
#
# Epoch: 3 	Training Loss: 1.838635 	Validation Loss: 1.666950
# Validation loss decreased (1.915924--> 1.666950).	Saving model ...
#
# Epoch: 4 	Training Loss: 1.648009 	Validation Loss: 1.514883
# Validation loss decreased (1.666950--> 1.514883).	Saving model ...
#
# Epoch: 5 	Training Loss: 1.535422 	Validation Loss: 1.423698
# Validation loss decreased (1.514883--> 1.423698).	Saving model ...
#
# Epoch: 6 	Training Loss: 1.454691 	Validation Loss: 1.394813
# Validation loss decreased (1.423698--> 1.394813).	Saving model ...
#
# Epoch: 7 	Training Loss: 1.385438 	Validation Loss: 1.333911
# Validation loss decreased (1.394813--> 1.333911).	Saving model ...
#
# Epoch: 8 	Training Loss: 1.323249 	Validation Loss: 1.261087
# Validation loss decreased (1.333911--> 1.261087).	Saving model ...
#
# Epoch: 9 	Training Loss: 1.265925 	Validation Loss: 1.218851
# Validation loss decreased (1.261087--> 1.218851).	Saving model ...
#
# Epoch: 10 	Training Loss: 1.205357 	Validation Loss: 1.158917
# Validation loss decreased (1.218851--> 1.158917).	Saving model ...
#
# Epoch: 11 	Training Loss: 1.159921 	Validation Loss: 1.106801
# Validation loss decreased (1.158917--> 1.106801).	Saving model ...
#
# Epoch: 12 	Training Loss: 1.105287 	Validation Loss: 1.056017
# Validation loss decreased (1.106801--> 1.056017).	Saving model ...
#
# Epoch: 13 	Training Loss: 1.056548 	Validation Loss: 1.009266
# Validation loss decreased (1.056017--> 1.009266).	Saving model ...
#
# Epoch: 14 	Training Loss: 1.013824 	Validation Loss: 0.984441
# Validation loss decreased (1.009266--> 0.984441).	Saving model ...
#
# Epoch: 15 	Training Loss: 0.973842 	Validation Loss: 0.933258
# Validation loss decreased (0.984441--> 0.933258).	Saving model ...
#
# Epoch: 16 	Training Loss: 0.931294 	Validation Loss: 0.923368
# Validation loss decreased (0.933258--> 0.923368).	Saving model ...
#
# Epoch: 17 	Training Loss: 0.898103 	Validation Loss: 0.892123
# Validation loss decreased (0.923368--> 0.892123).	Saving model ...
#
# Epoch: 18 	Training Loss: 0.862265 	Validation Loss: 0.897536
# Epoch: 19 	Training Loss: 0.825456 	Validation Loss: 0.832134
# Validation loss decreased (0.892123--> 0.832134).	Saving model ...
#
# Epoch: 20 	Training Loss: 0.796697 	Validation Loss: 0.811359
# Validation loss decreased (0.832134--> 0.811359).	Saving model ...
#
# Epoch: 21 	Training Loss: 0.757673 	Validation Loss: 0.786352
# Validation loss decreased (0.811359--> 0.786352).	Saving model ...
#
# Epoch: 22 	Training Loss: 0.732863 	Validation Loss: 0.808436
# Epoch: 23 	Training Loss: 0.703947 	Validation Loss: 0.759594
# Validation loss decreased (0.786352--> 0.759594).	Saving model ...
#
# Epoch: 24 	Training Loss: 0.676646 	Validation Loss: 0.755164
# Validation loss decreased (0.759594--> 0.755164).	Saving model ...
#
# Epoch: 25 	Training Loss: 0.648812 	Validation Loss: 0.752332
# Validation loss decreased (0.755164--> 0.752332).	Saving model ...
#
# Epoch: 26 	Training Loss: 0.619305 	Validation Loss: 0.732875
# Validation loss decreased (0.752332--> 0.732875).	Saving model ...
#
# Epoch: 27 	Training Loss: 0.594314 	Validation Loss: 0.710901
# Validation loss decreased (0.732875--> 0.710901).	Saving model ...
#
# Epoch: 28 	Training Loss: 0.569849 	Validation Loss: 0.728807
# Epoch: 29 	Training Loss: 0.547265 	Validation Loss: 0.739777
# Epoch: 30 	Training Loss: 0.521807 	Validation Loss: 0.729618
# Epoch: 31 	Training Loss: 0.498421 	Validation Loss: 0.701947
# Validation loss decreased (0.710901--> 0.701947).	Saving model ...
#
# Epoch: 32 	Training Loss: 0.472310 	Validation Loss: 0.696386
# Validation loss decreased (0.701947--> 0.696386).	Saving model ...
#
# Epoch: 33 	Training Loss: 0.444748 	Validation Loss: 0.710187
# Epoch: 34 	Training Loss: 0.420606 	Validation Loss: 0.704755
# Epoch: 35 	Training Loss: 0.399364 	Validation Loss: 0.758051
# Epoch: 36 	Training Loss: 0.375220 	Validation Loss: 0.752286
# Epoch: 37 	Training Loss: 0.359123 	Validation Loss: 0.723246
# Epoch: 38 	Training Loss: 0.332460 	Validation Loss: 0.714501
# Epoch: 39 	Training Loss: 0.308490 	Validation Loss: 0.729569
# Epoch: 40 	Training Loss: 0.293027 	Validation Loss: 0.735778
# Epoch: 41 	Training Loss: 0.273258 	Validation Loss: 0.805968
# Epoch: 42 	Training Loss: 0.253135 	Validation Loss: 0.782511
# Epoch: 43 	Training Loss: 0.235066 	Validation Loss: 0.784653
# Epoch: 44 	Training Loss: 0.216933 	Validation Loss: 0.782200
# Epoch: 45 	Training Loss: 0.204809 	Validation Loss: 0.832945
# Epoch: 46 	Training Loss: 0.183375 	Validation Loss: 0.824805
# Epoch: 47 	Training Loss: 0.172275 	Validation Loss: 0.821429
# Epoch: 48 	Training Loss: 0.165018 	Validation Loss: 0.832114
# Epoch: 49 	Training Loss: 0.153246 	Validation Loss: 0.856070
# Epoch: 50 	Training Loss: 0.143621 	Validation Loss: 0.850060

# %% [markdown]
# ## Tesing with the best Model

# %%
model.load_state_dict(torch.load('model.pt'))
# Out:
# <All keys matched successfully>

# %%
test_loss = 0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval()

for images, labels in test_loader:
    images, labels = images.to(device), labels.to(device)
    
    op = model(images)
    loss = criterion(op, labels)
    test_loss += loss.item()
    _, pred = torch.max(op, 1)
    correct = np.squeeze(pred.eq(labels.data.view_as(pred)))
#     print(correct)
    
    for i in range(batch_size):
        lb = labels.data[i]
        class_correct[lb] += correct[i].item()
        class_total[lb] += 1

test_loss = test_loss/len(test_loader)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.709687
#
# Test Accuracy of airplane: 86% (862/1000)
# Test Accuracy of automobile: 84% (849/1000)
# Test Accuracy of  bird: 63% (635/1000)
# Test Accuracy of   cat: 61% (612/1000)
# Test Accuracy of  deer: 69% (690/1000)
# Test Accuracy of   dog: 68% (688/1000)
# Test Accuracy of  frog: 82% (827/1000)
# Test Accuracy of horse: 78% (787/1000)
# Test Accuracy of  ship: 82% (824/1000)
# Test Accuracy of truck: 82% (820/1000)
#
# Test Accuracy (Overall): 75% (7594/10000)

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

train_on_gpu = torch.cuda.is_available()

# move model inputs to cuda, if GPU available
images = images.to(device)

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx] if not train_on_gpu else images[idx].cpu())
    ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))
# Out:
# <ipython-input-12-c8deb8c050d6>:20: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
